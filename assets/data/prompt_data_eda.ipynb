# %%
import pandas as pd
import json

# %%
raw_data = pd.read_csv('test_set_829.csv')

# %%
raw_data.head()
# Out:
#       ID                                      ENTIRE_PROMPT  \
# 0  43985  Chinese convo starter #1: 最近发生了一件很劲爆的事，你想听吗？\n...
# 1  95761  Chinese convo starter #1: 你最近经历了什么让人脸红心跳的事情？\n...
# 2  91269  Chinese convo starter #1: 最近有什么事情让你很生气吗？\nEngl...
# 3  81909  Chinese convo starter #1: 你不会相信，我最近遇到了一件瞎眼的事情！...
# 4  96907  Chinese convo starter #1: 最近有没有什么特别戏剧性的事情发生？\n...
#
#                    VIBE DETAILED_VIBE_YOU_CAN_IGNORE       SUB_VIBE  \
# 0  hai xiu / spicy talk           silly gossipy vibe  spill the tea
# 1  hai xiu / spicy talk           silly gossipy vibe  spill the tea
# 2  hai xiu / spicy talk           silly gossipy vibe  spill the tea
# 3  hai xiu / spicy talk           silly gossipy vibe  spill the tea
# 4  hai xiu / spicy talk           silly gossipy vibe  spill the tea
#
#                                   TITLE_DESCRIPTION  WORK_SAFETY_RATING  \
# 0  something dramatic that happened to you recently                   0
# ...

# %%
raw_dict = raw_data.to_dict(orient='records')

# %%
raw_dict[:1]
# Out:
# [{'ID': 43985,
# ...

# %%
# raw_data.to_json('test_set_829.json', orient='records')
file_path = "test_set_829.json"
with open(file_path, "w", encoding="utf-8") as json_file:
    # json.dump(list_of_dicts, json_file)
    json.dump(raw_dict, json_file, ensure_ascii=False)
